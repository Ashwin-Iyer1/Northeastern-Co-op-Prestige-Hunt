# %%
import json

# print keys

with open('response.json') as f:
    data = json.load(f)

companies = set()
for key in data['models']:
    companies.add(key['name'])
    
print(companies)
# Out:
# {'Mercury Systems, Inc.', 'Hallam Associates, Inc.', 'Salesforce.com, Inc.', "Blythedale Children's Hospital", 'Control Risks', 'Hartford Hospital  ', 'ASMPT NEXX, Inc.', 'Garage', 'Insight Investment', "Suffolk County Sheriff's Department", 'Automated Tire', 'Greentarget', 'AlphaSimplex', 'The Croft School-South End', 'Odyssey Reinsurance Company', 'Phoenix3 Collective', 'Tesla, Inc.', 'Secretary of the Commonwealth of Massachusetts', 'Holman Enterprises', "Prisoners' Legal Services (PLS)", 'Wolfe Research', 'Boston Engineering Corporation', 'Cengage', 'Alia Software Inc.', 'Beyer Blinder Belle', 'Takachar', 'Moody Street Dental ', 'Income Research and Management', 'Dance Molinari / Breaking Borders Performing Arts International', 'Habitat for Humanity Ireland', 'R.O.S.A. Remove Obstacles to Social Awareness', 'Tufts Medicine ', 'Klaviyo', 'Hermes of Paris', 'Western Digital Corporation', 'McLean Hospital', 'SlicPix', 'U.S. Coast Guard', 'Bedford Public Schools', 'Mathworks Inc.', '
# ...

# %%
from bs4 import BeautifulSoup

# list in html

html = """<ul><li class="bg-bg3 md:hover:bg-bg2 border border-foreground rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">1</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Anthropic</p></div><p class="text-foreground">1456</p></div></li><li class="bg-bg3 md:hover:bg-bg2 border border-foreground rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">2</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">OpenAI</p></div><p class="text-foreground">1445</p></div></li><li class="bg-bg3 md:hover:bg-bg2 border border-foreground rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">3</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Jane Street</p></div><p class="text-foreground">1411</p></div></li><li class="bg-bg2 md:hover:bg-bg1 border border-secondary rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">4</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Hudson River Trading</p></div><p class="text-foreground">1405</p></div></li><li class="bg-bg2 md:hover:bg-bg1 border border-secondary rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">5</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Deepmind</p></div><p class="text-foreground">1377</p></div></li><li class="bg-bg2 md:hover:bg-bg1 border border-secondary rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">6</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Citadel</p></div><p class="text-foreground">1358</p></div></li><li class="bg-bg2 md:hover:bg-bg1 border border-secondary rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">7</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Nvidia</p></div><p class="text-foreground">1346</p></div></li><li class="bg-bg2 md:hover:bg-bg1 border border-secondary rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">8</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Google</p></div><p class="text-foreground">1334</p></div></li><li class="bg-bg2 md:hover:bg-bg1 border border-secondary rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">9</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Meta</p></div><p class="text-foreground">1331</p></div></li><li class="bg-bg2 md:hover:bg-bg1 border border-secondary rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">10</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Netflix</p></div><p class="text-foreground">1325</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">11</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">Databricks</p></div><p class="text-foreground">1300</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">12</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Two Sigma</p></div><p class="text-foreground">1274</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">13</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Apple</p></div><p class="text-foreground">1270</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">14</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">3</p></div></p><p class="text-foreground">Radix Trading</p></div><p class="text-foreground">1252</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">15</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Optiver</p></div><p class="text-foreground">1244</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">16</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Stripe</p></div><p class="text-foreground">1240</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">17</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Jump Trading</p></div><p class="text-foreground">1239</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">18</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">Waymo</p></div><p class="text-foreground">1228</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">19</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Renaissance Technologies</p></div><p class="text-foreground">1228</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">20</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">IMC Trading</p></div><p class="text-foreground">1219</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">21</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Five Rings</p></div><p class="text-foreground">1197</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">22</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Airbnb</p></div><p class="text-foreground">1194</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">23</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">11</p></div></p><p class="text-foreground">Cursor</p></div><p class="text-foreground">1194</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">24</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Roblox</p></div><p class="text-foreground">1191</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">25</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">D.E. Shaw</p></div><p class="text-foreground">1186</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">26</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">5</p></div></p><p class="text-foreground">Palantir</p></div><p class="text-foreground">1184</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">27</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">5</p></div></p><p class="text-foreground">Snowflake</p></div><p class="text-foreground">1169</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">28</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Uber</p></div><p class="text-foreground">1164</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">29</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">SpaceX</p></div><p class="text-foreground">1163</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">30</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Microsoft</p></div><p class="text-foreground">1162</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">31</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Coinbase</p></div><p class="text-foreground">1141</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">32</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Figma</p></div><p class="text-foreground">1130</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">33</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">5</p></div></p><p class="text-foreground">DoorDash</p></div><p class="text-foreground">1130</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">34</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Scale AI</p></div><p class="text-foreground">1126</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">35</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Notion</p></div><p class="text-foreground">1119</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">36</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Pinterest</p></div><p class="text-foreground">1109</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">37</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">9</p></div></p><p class="text-foreground">Hugging Face</p></div><p class="text-foreground">1105</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">38</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Tesla</p></div><p class="text-foreground">1105</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">39</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Ramp</p></div><p class="text-foreground">1103</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">40</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Akuna Capital</p></div><p class="text-foreground">1098</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">41</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">6</p></div></p><p class="text-foreground">LinkedIn</p></div><p class="text-foreground">1094</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">42</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Datadog</p></div><p class="text-foreground">1087</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">43</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">GitHub</p></div><p class="text-foreground">1081</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">44</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">8</p></div></p><p class="text-foreground">Square</p></div><p class="text-foreground">1079</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">45</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">31</p></div></p><p class="text-foreground">xAI</p></div><p class="text-foreground">1068</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">46</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">5</p></div></p><p class="text-foreground">Amazon</p></div><p class="text-foreground">1066</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">47</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">14</p></div></p><p class="text-foreground">Reddit</p></div><p class="text-foreground">1057</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">48</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">5</p></div></p><p class="text-foreground">Anduril</p></div><p class="text-foreground">1056</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">49</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Discord</p></div><p class="text-foreground">1055</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">50</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Robinhood</p></div><p class="text-foreground">1055</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">51</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">8</p></div></p><p class="text-foreground">X</p></div><p class="text-foreground">1053</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">52</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">6</p></div></p><p class="text-foreground">Bloomberg</p></div><p class="text-foreground">1050</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">53</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Lyft</p></div><p class="text-foreground">1046</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">54</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">8</p></div></p><p class="text-foreground">Snap</p></div><p class="text-foreground">1046</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">55</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">11</p></div></p><p class="text-foreground">Neuralink</p></div><p class="text-foreground">1046</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">56</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">NASA</p></div><p class="text-foreground">1045</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">57</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">9</p></div></p><p class="text-foreground">ByteDance</p></div><p class="text-foreground">1045</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">58</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">4</p></div></p><p class="text-foreground">Blue Origin</p></div><p class="text-foreground">1044</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">59</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">MongoDB</p></div><p class="text-foreground">1037</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">60</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">10</p></div></p><p class="text-foreground">Spotify</p></div><p class="text-foreground">1036</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">61</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">6</p></div></p><p class="text-foreground">Plaid</p></div><p class="text-foreground">1033</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">62</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Dropbox</p></div><p class="text-foreground">1031</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">63</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">7</p></div></p><p class="text-foreground">Duolingo</p></div><p class="text-foreground">1031</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">64</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Salesforce</p></div><p class="text-foreground">1029</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">65</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Slack</p></div><p class="text-foreground">1023</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">66</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">Adobe</p></div><p class="text-foreground">1017</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">67</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">7</p></div></p><p class="text-foreground">Flow Traders</p></div><p class="text-foreground">1016</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">68</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Cloudflare</p></div><p class="text-foreground">1011</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">69</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Twitch</p></div><p class="text-foreground">1003</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">70</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Blackrock</p></div><p class="text-foreground">1001</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">71</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">5</p></div></p><p class="text-foreground">Shopify</p></div><p class="text-foreground">998</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">72</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Goldman Sachs</p></div><p class="text-foreground">990</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">73</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Bytedance</p></div><p class="text-foreground">989</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">74</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Atlassian</p></div><p class="text-foreground">971</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">75</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">Riot Games</p></div><p class="text-foreground">961</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">76</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Oracle</p></div><p class="text-foreground">957</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">77</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">20</p></div></p><p class="text-foreground">Palo Alto Networks</p></div><p class="text-foreground">952</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">78</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">14</p></div></p><p class="text-foreground">Cohere</p></div><p class="text-foreground">949</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">79</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">PayPal</p></div><p class="text-foreground">947</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">80</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">10</p></div></p><p class="text-foreground">Airtable</p></div><p class="text-foreground">945</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">81</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">5</p></div></p><p class="text-foreground">Capital One</p></div><p class="text-foreground">943</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">82</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">JPMC</p></div><p class="text-foreground">931</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">83</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Brex</p></div><p class="text-foreground">928</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">84</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">4</p></div></p><p class="text-foreground">Asana</p></div><p class="text-foreground">927</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">85</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Nuro</p></div><p class="text-foreground">923</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">86</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">7</p></div></p><p class="text-foreground">Rippling</p></div><p class="text-foreground">921</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">87</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">5</p></div></p><p class="text-foreground">Zoom</p></div><p class="text-foreground">919</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">88</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">5</p></div></p><p class="text-foreground">Disney</p></div><p class="text-foreground">912</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">89</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">IBM</p></div><p class="text-foreground">911</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">90</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Morgan Stanley</p></div><p class="text-foreground">908</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">91</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Instacart</p></div><p class="text-foreground">908</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">92</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">26</p></div></p><p class="text-foreground">Voleon</p></div><p class="text-foreground">907</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">93</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">4</p></div></p><p class="text-foreground">Okta</p></div><p class="text-foreground">905</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">94</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Intel</p></div><p class="text-foreground">903</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">95</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Autodesk</p></div><p class="text-foreground">899</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">96</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">11</p></div></p><p class="text-foreground">Canva</p></div><p class="text-foreground">891</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">97</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">8</p></div></p><p class="text-foreground">Lockheed Martin</p></div><p class="text-foreground">890</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">98</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">4</p></div></p><p class="text-foreground">Splunk</p></div><p class="text-foreground">877</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">99</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Cisco</p></div><p class="text-foreground">872</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">100</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Intuit</p></div><p class="text-foreground">870</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">101</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">5</p></div></p><p class="text-foreground">Twilio</p></div><p class="text-foreground">868</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">102</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Cruise</p></div><p class="text-foreground">854</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">103</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Red Hat</p></div><p class="text-foreground">852</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">104</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Quora</p></div><p class="text-foreground">849</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">105</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">HubSpot</p></div><p class="text-foreground">849</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">106</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">8</p></div></p><p class="text-foreground">Glean</p></div><p class="text-foreground">849</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">107</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">5</p></div></p><p class="text-foreground">Hulu</p></div><p class="text-foreground">848</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">108</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">ServiceNow</p></div><p class="text-foreground">827</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">109</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Ebay</p></div><p class="text-foreground">827</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">110</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">5</p></div></p><p class="text-foreground">Samsung</p></div><p class="text-foreground">823</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">111</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">4</p></div></p><p class="text-foreground">Zillow</p></div><p class="text-foreground">817</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">112</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Expedia</p></div><p class="text-foreground">817</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">113</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Box</p></div><p class="text-foreground">815</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">114</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">GrubHub</p></div><p class="text-foreground">813</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">115</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Docusign</p></div><p class="text-foreground">812</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">116</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">5</p></div></p><p class="text-foreground">Samsara</p></div><p class="text-foreground">811</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">117</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Affirm</p></div><p class="text-foreground">802</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">118</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">8</p></div></p><p class="text-foreground">VMware</p></div><p class="text-foreground">796</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">119</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Etsy</p></div><p class="text-foreground">795</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">120</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">6</p></div></p><p class="text-foreground">Walmart</p></div><p class="text-foreground">792</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">121</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Indeed</p></div><p class="text-foreground">788</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">122</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Workday</p></div><p class="text-foreground">783</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">123</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">4</p></div></p><p class="text-foreground">Tableau</p></div><p class="text-foreground">771</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">124</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">4</p></div></p><p class="text-foreground">Nutanix</p></div><p class="text-foreground">765</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">125</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Yelp</p></div><p class="text-foreground">762</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">126</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Qualtrics</p></div><p class="text-foreground">762</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">127</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Bolt</p></div><p class="text-foreground">761</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">128</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">6</p></div></p><p class="text-foreground">Elastic</p></div><p class="text-foreground">757</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">129</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Postmates</p></div><p class="text-foreground">751</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">130</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Verily</p></div><p class="text-foreground">749</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">131</p><p class="text-foreground mr-3"><img width="20" height="20" src="/horizontal-line.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"></p><p class="text-foreground">Nextdoor</p></div><p class="text-foreground">727</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">132</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">9</p></div></p><p class="text-foreground">Carvana</p></div><p class="text-foreground">713</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">133</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Flexport</p></div><p class="text-foreground">696</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">134</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">1</p></div></p><p class="text-foreground">Redfin</p></div><p class="text-foreground">692</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">135</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Peloton</p></div><p class="text-foreground">680</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">136</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Addepar</p></div><p class="text-foreground">679</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">137</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Wish</p></div><p class="text-foreground">674</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">138</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" src="/up-arrow-green.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-green ml-1">2</p></div></p><p class="text-foreground">Retool</p></div><p class="text-foreground">650</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">139</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">2</p></div></p><p class="text-foreground">Kayak</p></div><p class="text-foreground">647</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">140</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">1</p></div></p><p class="text-foreground">Tanium</p></div><p class="text-foreground">634</p></div></li><li class="bg-bg1 md:hover:bg-background border border-bg3 rounded-xl shadow-md px-6 md:px-20 py-5 my-2 hover:cursor-pointer relative"><div class="flex flex-row justify-between font-semibold"><div class="flex flex-row"><p class="mr-4 text-foreground">141</p><p class="text-foreground mr-3"><div class="flex items-center"><img width="20" height="20" class="rotate-180" src="/up-arrow-red.svg?__frsh_c=d0fc45e42604ab53e5618765c55a50209eaf5f6a"><p class="text-xs text-red ml-1">3</p></div></p><p class="text-foreground">Yext</p></div><p class="text-foreground">630</p></div></li></ul>"""

# %%
# convert to a list of dicts
soup = BeautifulSoup(html, 'html.parser')
companies_initial_rank = []
for li in soup.find_all('li'):
    company = {}
    ps = li.find_all('p', class_='text-foreground')
    company['rank'] = int(ps[0].text)
    company['name'] = str(ps[2].text)
    company['score'] = int(ps[3].text)
    companies_initial_rank.append(company)

# %%
companies_initial_rank
# Out:
# [{'rank': 1, 'name': 'Anthropic', 'score': 1456},
#  {'rank': 2, 'name': 'OpenAI', 'score': 1445},
#  {'rank': 3, 'name': 'Jane Street', 'score': 1411},
#  {'rank': 4, 'name': 'Hudson River Trading', 'score': 1405},
#  {'rank': 5, 'name': 'Deepmind', 'score': 1377},
#  {'rank': 6, 'name': 'Citadel', 'score': 1358},
#  {'rank': 7, 'name': 'Nvidia', 'score': 1346},
#  {'rank': 8, 'name': 'Google', 'score': 1334},
#  {'rank': 9, 'name': 'Meta', 'score': 1331},
#  {'rank': 10, 'name': 'Netflix', 'score': 1325},
#  {'rank': 11, 'name': 'Databricks', 'score': 1300},
#  {'rank': 12, 'name': 'Two Sigma', 'score': 1274},
#  {'rank': 13, 'name': 'Apple', 'score': 1270},
#  {'rank': 14, 'name': 'Radix Trading', 'score': 1252},
#  {'rank': 15, 'name': 'Optiver', 'score': 1244},
#  {'rank': 16, 'name': 'Stripe', 'score': 1240},
#  {'rank': 17, 'name': 'Jump Trading', 'score': 1239},
#  {'rank': 18, 'name': 'Waymo', 'score': 1228},
# ...

# %%
# Create a lookup dictionary with normalized names for the initial rank list
initial_rank_lookup = {}
for c in companies_initial_rank:
    normalized_name = c['name'].lower().strip()
    initial_rank_lookup[normalized_name] = c

comapnies_with_rank = {}

for company in companies:
    # Normalize the company name for comparison
    normalized_company = company.lower().strip()
    
    # if company is in the initial rank list, add the score to the comapnies_with_rank dict, else add it with a score of 0
    if normalized_company in initial_rank_lookup:
        company_data = initial_rank_lookup[normalized_company]
        comapnies_with_rank[normalized_company] = {'name': company_data['name'], 'score': company_data['score']}
    else:
        comapnies_with_rank[normalized_company] = {'name': company, 'score': 0}

comapnies_with_rank = list(comapnies_with_rank.values())
comapnies_with_rank.sort(key=lambda x: x['score'], reverse=True)
comapnies_with_rank
# Out:
# [{'name': 'Netflix', 'score': 1325},
#  {'name': 'SpaceX', 'score': 1163},
#  {'name': 'Neuralink', 'score': 1046},
#  {'name': 'Lyft', 'score': 1046},
#  {'name': 'Blue Origin', 'score': 1044},
#  {'name': 'Dropbox', 'score': 1031},
#  {'name': 'Palo Alto Networks', 'score': 952},
#  {'name': 'Morgan Stanley', 'score': 908},
#  {'name': 'Cisco', 'score': 872},
#  {'name': 'HubSpot', 'score': 849},
#  {'name': 'Mercury Systems, Inc.', 'score': 0},
#  {'name': 'Hallam Associates, Inc.', 'score': 0},
#  {'name': 'Salesforce.com, Inc.', 'score': 0},
#  {'name': "Blythedale Children's Hospital", 'score': 0},
#  {'name': 'Control Risks', 'score': 0},
#  {'name': 'Hartford Hospital  ', 'score': 0},
#  {'name': 'ASMPT NEXX, Inc.', 'score': 0},
#  {'name': 'Garage', 'score': 0},
#  {'name': 'Insight Investment', 'score': 0},
#  {'name': "Suffolk County Sheriff's Department", 'score': 0},
#  {'name': 'Automated Tire', 'score': 0},
#  {'name': 'Greentarget', 'score': 0},
# ...

# %%
# save companies with rank to a json file
import json

with open('companies_with_rank.json', 'w') as f:
    json.dump(comapnies_with_rank, f, indent=4)
